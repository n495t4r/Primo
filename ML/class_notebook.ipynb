# %%
import pandas as pd
import plotly.express as px
from category_encoders import *
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('../Data/loan_Default.csv',encoding='iso-8859-1')

# %%
df.head()
# Out:
#        LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  I38PQUQS96   56   85994       50587          520              80
# 1  HPSK72WA7R   69   50432      124440          458              15
# 2  C1OZ6DPJ8Y   46   84208      129188          451              26
# 3  V2KKSFM3UN   32   31713       44799          743               0
# 4  EY08JDHTZP   60   20437        9139          633               8
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0               4         15.23        36      0.44   Bachelor's
# 1               1          4.81        60      0.68     Master's
# 2               3         21.17        24      0.31     Master's
# 3               3          7.07        24      0.23  High School
# 4               4          6.51        48      0.73   Bachelor's
#
#   EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0      Full-time      divorced         Yes           Yes       Other
# ...

# %%
df['MaritalStatus'].unique()
# Out:
# array(['divorced', 'Married', 'Divorced', 'SingleSDDF', 'Single',
#        'Married\x85', 'SINGLE'], dtype=object)

# %%
fix={
    'divorced':'Divorced',
    'Married\x85':'Married',
    'SingleSDDF':'Single',
    'SINGLE':'Single'
}

# %%
df['MaritalStatus']=df['MaritalStatus'].replace(fix)

# %%
df.head(3)
# Out:
#        LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  I38PQUQS96   56   85994       50587          520              80
# 1  HPSK72WA7R   69   50432      124440          458              15
# 2  C1OZ6DPJ8Y   46   84208      129188          451              26
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio   Education  \
# 0               4         15.23        36      0.44  Bachelor's
# 1               1          4.81        60      0.68    Master's
# 2               3         21.17        24      0.31    Master's
#
#   EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0      Full-time      Divorced         Yes           Yes       Other
# 1      Full-time       Married          No            No       Other
# 2     Unemployed      Divorced         Yes           Yes        Auto
#
#   HasCoSigner  Default
# 0         Yes        0
# 1         Yes        0
# 2          No        1

# %%
primo['NumCreditLines']=primo['NumCreditLines'].astype('str')

# %%
enc = OrdinalEncoder()

# %%
primo=df.copy()

# %%
string_col=['Education', 'EmploymentType', 'MaritalStatus',
       'HasMortgage', 'HasDependents', 'LoanPurpose', 'HasCoSigner','NumCreditLines']

# %%
primo[string_col]=enc.fit_transform(primo[string_col])

# %%
df.head(3)
# Out:
#        LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  I38PQUQS96   56   85994       50587          520              80
# 1  HPSK72WA7R   69   50432      124440          458              15
# 2  C1OZ6DPJ8Y   46   84208      129188          451              26
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio   Education  \
# 0               4         15.23        36      0.44  Bachelor's
# 1               1          4.81        60      0.68    Master's
# 2               3         21.17        24      0.31    Master's
#
#   EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0      Full-time      Divorced         Yes           Yes       Other
# 1      Full-time       Married          No            No       Other
# 2     Unemployed      Divorced         Yes           Yes        Auto
#
#   HasCoSigner  Default
# 0         Yes        0
# 1         Yes        0
# 2          No        1

# %%
primo.head(3)
# Out:
#        LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  I38PQUQS96   56   85994       50587          520              80
# 1  HPSK72WA7R   69   50432      124440          458              15
# 2  C1OZ6DPJ8Y   46   84208      129188          451              26
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio  Education  \
# 0               4         15.23        36      0.44          1
# 1               1          4.81        60      0.68          2
# 2               3         21.17        24      0.31          2
#
#    EmploymentType  MaritalStatus  HasMortgage  HasDependents  LoanPurpose  \
# 0               1              1            1              1            1
# 1               1              2            2              2            1
# 2               2              1            1              1            2
#
#    HasCoSigner  Default
# 0            1        0
# 1            1        0
# 2            2        1

# %%
target=primo['Default']

# %%
primo_final=primo.drop(columns=['LoanID','Default'])

# %%
X_train, X_test, y_train, y_test = train_test_split(primo_final, target, test_size=0.3, random_state=42)

# %%
logistic_model = LogisticRegression()

# %%
logistic_model
# Out:
# LogisticRegression()

# %%
logistic_model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
logistic_preds=logistic_model.predict(X_test)

# %%
logistic_accuracy = accuracy_score(y_test, logistic_preds)

# %%
logistic_accuracy
# Out:
# 0.8835976763918805

# %%
test=pd.DataFrame({'ACTUAL':y_test,'PREDICTED':logistic_preds})

# %%
test[:50]
# Out:
#         ACTUAL  PREDICTED
# 51139        0          0
# 71005        0          0
# 35684        0          0
# 174087       0          0
# 137952       0          0
# 137678       0          0
# 74249        0          0
# 253344       0          0
# 219115       0          0
# 144898       0          0
# 180445       0          0
# 129150       0          0
# 158333       0          0
# 195656       0          0
# 41524        0          0
# 129379       0          0
# 87551        0          0
# 204450       0          0
# 86953        0          0
# 247337       1          0
# 195846       0          0
# 37176        0          0
# 189700       1          0
# 228299       0          0
# 230066       0          0
# 90323        0          0
# 71584        0          0
# 75158        0          0
# 158991       0          0
# 119112       0          0
# 29603        0          0
# 192733       0          0
# 247913       0          0
# 118258       0          0
# ...

# %%
logistic_model = LogisticRegression()
logistic_model.fit(X_train, y_train)
logistic_preds = logistic_model.predict(X_test)
logistic_accuracy = accuracy_score(y_test, logistic_preds)
logistic_precision = precision_score(y_test, logistic_preds)
logistic_recall = recall_score(y_test, logistic_preds)
logistic_f1 = f1_score(y_test, logistic_preds)
logistic_confusion_matrix = confusion_matrix(y_test, logistic_preds)
